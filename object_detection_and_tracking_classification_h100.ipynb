# %% [markdown]
# #### DeepStream 8.0 - Multi-Class Object Detection with Tracking & Attribute Classification
#
# This notebook demonstrates a comprehensive DeepStream pipeline for:
# - **Primary object detection** (vehicles, persons, bicycles, road signs)
# - **Object tracking** across frames
# - **Secondary inference** for vehicle attributes (color, make, type)
# - **On-Screen Display** with attribute overlay
#
#
# **Pipeline Flow:**
# ```
# filesrc → h264parse → nvv4l2decoder → nvstreammux →
# pgie (primary detector) → nvtracker →
# sgie1 (car type) → sgie2 (car make)  →
# nvvideoconvert → nvdsosd → nvvideoconvert → capsfilter →
# videoconvert → x264enc → h264parse → mp4mux → filesink
# ```

# %% [markdown]
# ## Introduction to Multi-DNN pipeline
#
# #In the previous notebook we learnt on how to make a simple DeepStream pipeline for object detection. In this notebook we take the idea forward and learn to build a  multi-class object detection,tracking and attribute classification pipeline
#
#
# **Contents of this Notebook :**
#
#
#
# ![test2](images/test2.png)
#
# We can explore the architecture diagram of the application. Here, we have 3 additional models that identify car color, make and type respectively. Plugging in additional models is like adding the original classifier, however there are configuration considerations to take care of.A new idea that we will be using in this notebook is the nvtracker plugin.
#
# ### Changes in configuration
#
# Because these secondary classifiers are only intended to execute on objects that we believe are vehicles, we will need to add new configuration parameters to generate this behavior.Two new parameters, `operate-on-gie-id` and `operate-on-class-ids` will let us control this behavior.
#
# The first, `operate-on-gie-id`, lets us configure a classifier to only execute on objects from a
# different classifier. In this case, we will configure the secondary classifier to only execute on
# objects detected by the primary classifier. The second, `operate-on-class-ids`, lets us configure a
# classifier to only execute on objects of a specific class. By combining these two, our secondary
# classifiers will be configured to only evaluate the make, model, and color of objects classified as
# cars by our primary model.

# %%
# Import Required Libraries
import sys
import time

sys.path.append('/opt/nvidia/deepstream/deepstream-8.0/sources/deepstream_python_apps/apps')

import gi
gi.require_version('Gst', '1.0')
from gi.repository import GObject, Gst, GLib
from common.bus_call import bus_call
import pyds

Gst.init(None)
# Out:
# []

# %%
# Object class IDs
PGIE_CLASS_ID_VEHICLE = 0
PGIE_CLASS_ID_BICYCLE = 1
PGIE_CLASS_ID_PERSON = 2
PGIE_CLASS_ID_ROADSIGN = 3

# Input/Output paths
INPUT_VIDEO_NAME = '/opt/nvidia/deepstream/deepstream-8.0/samples/streams/sample_720p.h264'
OUTPUT_VIDEO_NAME = '/app/notebooks/ds_out_multiclass.mp4'

PGIE_CONFIG_FILE = '/app/notebooks/dstest2_pgie_config.txt'

SGIE1_CONFIG_FILE = '/app/notebooks/dstest2_sgie1_config.txt'  # Car make
SGIE2_CONFIG_FILE = '/app/notebooks/dstest2_sgie2_config.txt'  # Car type

TRACKER_LIB = '/opt/nvidia/deepstream/deepstream-8.0/lib/libnvds_nvmultiobjecttracker.so'

print(f" Input video: {INPUT_VIDEO_NAME}")
print(f" Output video: {OUTPUT_VIDEO_NAME}")
print(f"  Primary GIE config: {PGIE_CONFIG_FILE}")
print(f"  SGIE1 config (Color): {SGIE1_CONFIG_FILE}")
print(f"  SGIE2 config (Make/Type): {SGIE2_CONFIG_FILE}")
print(f" Tracker library: {TRACKER_LIB}")
# Out:
#  Input video: /opt/nvidia/deepstream/deepstream-8.0/samples/streams/sample_720p.h264
#  Output video: /app/notebooks/ds_out_multiclass.mp4
#   Primary GIE config: /app/notebooks/dstest2_pgie_config.txt
#   SGIE1 config (Color): /app/notebooks/dstest2_sgie1_config.txt
#   SGIE2 config (Make/Type): /app/notebooks/dstest2_sgie2_config.txt
#  Tracker library: /opt/nvidia/deepstream/deepstream-8.0/lib/libnvds_nvmultiobjecttracker.so

# %%
def make_elm_or_print_err(factoryname, name, printedname, detail=""):
    """Create a GStreamer element or print error message"""
    print(f"Creating {printedname}...")
    elm = Gst.ElementFactory.make(factoryname, name)
    if not elm:
        sys.stderr.write(f"Unable to create {printedname}\n")
    if detail:
            sys.stderr.write(detail)
    return elm

print(" Helper function defined")
# Out:
#  Helper function defined

# %%
print("\n" + "="*60)
print("CREATING PIPELINE")
print("="*60)
pipeline = Gst.Pipeline()
if not pipeline:
    sys.stderr.write("Unable to create Pipeline\n")
source = make_elm_or_print_err("filesrc", "file-source", "Source")
h264parser = make_elm_or_print_err("h264parse", "h264-parser", "H264 Parser")
decoder = make_elm_or_print_err("nvv4l2decoder", "nvv4l2-decoder", "NV Decoder")
streammux = make_elm_or_print_err("nvstreammux", "stream-muxer", "Stream Muxer")
pgie = make_elm_or_print_err("nvinfer", "primary-inference", "Primary Inference")
tracker = make_elm_or_print_err("nvtracker", "tracker", "NV Tracker")

sgie1 = make_elm_or_print_err("nvinfer", "secondary1-nvinference-engine", "Secondary Inference 1 (Color)")
sgie2 = make_elm_or_print_err("nvinfer", "secondary2-nvinference-engine", "Secondary Inference 2 (Make/Type)")

nvvidconv = make_elm_or_print_err("nvvideoconvert", "convertor", "NV Video Converter 1")
nvosd = make_elm_or_print_err("nvdsosd", "onscreendisplay", "On-Screen Display")
nvvidconv2 = make_elm_or_print_err("nvvideoconvert", "convertor2", "NV Video Converter 2")
capsfilter = make_elm_or_print_err("capsfilter", "caps", "Caps Filter")
sw_videoconvert = make_elm_or_print_err("videoconvert", "sw-videoconvert", "Software Video Converter")

# H100: Use x264enc software encoder
encoder = make_elm_or_print_err("x264enc", "encoder", "H264 Software Encoder")
h264parser2 = make_elm_or_print_err("h264parse", "h264-parser2", "H264 Parser 2")
mp4mux = make_elm_or_print_err("mp4mux", "mp4mux", "MP4 Muxer")
sink = make_elm_or_print_err("filesink", "filesink", "File Sink")

print("\n All elements created successfully!")
# Out:
# ============================================================
# CREATING PIPELINE
# ============================================================
# Creating Source...
# Creating H264 Parser...
# Creating NV Decoder...
# Creating Stream Muxer...
# Creating Primary Inference...
# Creating NV Tracker...
# Creating Secondary Inference 1 (Color)...
# Creating Secondary Inference 2 (Make/Type)...
# Creating NV Video Converter 1...
# Creating On-Screen Display...
# Creating NV Video Converter 2...
# Creating Caps Filter...
# Creating Software Video Converter...
# Creating H264 Software Encoder...
# Creating H264 Parser 2...
# Creating MP4 Muxer...
# Creating File Sink...
#
#  All elements created successfully!

# %%
# Configure element properties

print("\n" + "="*60)
print("CONFIGURING ELEMENTS")
print("="*60)

# Source: Set input file
source.set_property('location', INPUT_VIDEO_NAME)
print(f"Source location: {INPUT_VIDEO_NAME}")

# Streammux: Set batch properties
streammux.set_property('width', 1920)
streammux.set_property('height', 1080)
streammux.set_property('batch-size', 1)
streammux.set_property('batched-push-timeout', 4000000)
print("Stream muxer: 1920x1080, batch-size=1")

# Primary inference: Set config file
pgie.set_property('config-file-path', PGIE_CONFIG_FILE)
print(f"Primary GIE config: {PGIE_CONFIG_FILE}")

# Tracker: Configure tracker properties
tracker.set_property('tracker-width', 640)
tracker.set_property('tracker-height', 384)
tracker.set_property('ll-lib-file', TRACKER_LIB)
tracker.set_property('ll-config-file', '/opt/nvidia/deepstream/deepstream-8.0/samples/configs/deepstream-app/config_tracker_NvDCF_perf.yml')
tracker.set_property('gpu-id', 0)
print("Tracker configured: NvDCF")

# Secondary inference 1: Car make
sgie1.set_property('config-file-path', SGIE1_CONFIG_FILE)
print(f"SGIE1 config (Type): {SGIE1_CONFIG_FILE}")

# Secondary inference 2: Car type
sgie2.set_property('config-file-path', SGIE2_CONFIG_FILE)
print(f"SGIE2 config (Make/Type): {SGIE2_CONFIG_FILE}")
caps = Gst.Caps.from_string("video/x-raw, format=I420")
capsfilter.set_property("caps", caps)
print("Caps filter: I420 format")
encoder.set_property('bitrate', 4000)  # x264enc uses kbps
encoder.set_property('speed-preset', 'ultrafast')
encoder.set_property('tune', 'zerolatency')
print("Encoder bitrate: 4 Mbps")

# Sink: Set output file
sink.set_property('location', OUTPUT_VIDEO_NAME)
sink.set_property('sync', False)
print(f"Output file: {OUTPUT_VIDEO_NAME}")
# Out:
# ============================================================
# CONFIGURING ELEMENTS
# ============================================================
# Source location: /opt/nvidia/deepstream/deepstream-8.0/samples/streams/sample_720p.h264
# Stream muxer: 1920x1080, batch-size=1
# Primary GIE config: /app/notebooks/dstest2_pgie_config.txt
# Tracker configured: NvDCF
# SGIE1 config (Type): /app/notebooks/dstest2_sgie1_config.txt
# SGIE2 config (Make/Type): /app/notebooks/dstest2_sgie2_config.txt
# Caps filter: I420 format
# Encoder bitrate: 4 Mbps
# Output file: /app/notebooks/ds_out_multiclass.mp4

# %%
print("\n" + "="*60)
print("BUILDING PIPELINE")
print("="*60)

# Add all elements to pipeline
print("Adding elements to pipeline...")
pipeline.add(source)
pipeline.add(h264parser)
pipeline.add(decoder)
pipeline.add(streammux)
pipeline.add(pgie)
pipeline.add(tracker)
pipeline.add(sgie1)
pipeline.add(sgie2)
pipeline.add(nvvidconv)
pipeline.add(nvosd)
pipeline.add(nvvidconv2)
pipeline.add(capsfilter)
pipeline.add(sw_videoconvert)  # H100: Software converter
pipeline.add(encoder)
pipeline.add(h264parser2)
pipeline.add(mp4mux)
pipeline.add(sink)
print("All elements added")

# Link elements
print("\nLinking elements...")
source.link(h264parser)
h264parser.link(decoder)

# Create pads for streammux (special case)
sinkpad = streammux.get_request_pad("sink_0")
if not sinkpad:
    sys.stderr.write("Unable to get sink pad of streammux\n")
srcpad = decoder.get_static_pad("src")
if not srcpad:
    sys.stderr.write("Unable to get source pad of decoder\n")
srcpad.link(sinkpad)
streammux.link(pgie)
pgie.link(tracker)
tracker.link(sgie1)
sgie1.link(sgie2)
sgie2.link(nvvidconv)
nvvidconv.link(nvosd)
nvosd.link(nvvidconv2)
nvvidconv2.link(capsfilter)
capsfilter.link(sw_videoconvert)  # H100: GPU→CPU
sw_videoconvert.link(encoder)  # H100: x264enc reads CPU memory
encoder.link(h264parser2)
h264parser2.link(mp4mux)
mp4mux.link(sink)

print("All elements linked")
print("\nPipeline built successfully")
# Out:
# ============================================================
# BUILDING PIPELINE
# ============================================================
# Adding elements to pipeline...
# All elements added
#
# Linking elements...
# All elements linked
#
# Pipeline built successfully
# /tmp/ipykernel_267/3754683117.py:32: DeprecationWarning: Gst.Element.get_request_pad is deprecated
#   sinkpad = streammux.get_request_pad("sink_0")

# %%
# Define metadata probe function with secondary classifier support

def osd_sink_pad_buffer_probe(pad, info, u_data):
    """Callback function to process metadata from each frame including secondary classifiers"""
    
    # Initialize object counter
    obj_counter = {
        PGIE_CLASS_ID_VEHICLE: 0,
        PGIE_CLASS_ID_PERSON: 0,
        PGIE_CLASS_ID_BICYCLE: 0,
        PGIE_CLASS_ID_ROADSIGN: 0
    }
    
    frame_number = 0
    num_rects = 0
    
    gst_buffer = info.get_buffer()
    if not gst_buffer:
        print("Unable to get GstBuffer")
        return Gst.PadProbeReturn.OK

    # Retrieve batch metadata from buffer
    batch_meta = pyds.gst_buffer_get_nvds_batch_meta(hash(gst_buffer))
    l_frame = batch_meta.frame_meta_list
    
    while l_frame is not None:
        try:
            frame_meta = pyds.NvDsFrameMeta.cast(l_frame.data)
        except StopIteration:
            break
        
        frame_number = frame_meta.frame_num
        num_rects = frame_meta.num_obj_meta
        l_obj = frame_meta.obj_meta_list
        
        # Process each object
        while l_obj is not None:
            try:
                obj_meta = pyds.NvDsObjectMeta.cast(l_obj.data)
            except StopIteration:
                break
            
            obj_counter[obj_meta.class_id] += 1
            
            # Extract vehicle attributes from secondary classifiers
            if obj_meta.class_id == PGIE_CLASS_ID_VEHICLE:
                vehicle_color = "Unknown"
                vehicle_make_type = "Unknown"
                
                # Iterate through classifier metadata
                l_classifier = obj_meta.classifier_meta_list
                while l_classifier is not None:
                    try:
                        classifier_meta = pyds.NvDsClassifierMeta.cast(l_classifier.data)
                        l_label = classifier_meta.label_info_list
                        
                        while l_label is not None:
                            try:
                                label_info = pyds.NvDsLabelInfo.cast(l_label.data)
                                
                                if classifier_meta.unique_component_id == 2:  
                                    vehicle_color = label_info.result_label
                                elif classifier_meta.unique_component_id == 3:
                                    vehicle_make_type = label_info.result_label
                                
                                l_label = l_label.next
                            except StopIteration:
                                break
                        
                        l_classifier = l_classifier.next
                    except StopIteration:
                        break
                
                # Add text display for vehicle attributes
                if vehicle_color != "Unknown" or vehicle_make_type != "Unknown":
                    display_meta = pyds.nvds_acquire_display_meta_from_pool(batch_meta)
                    display_meta.num_labels = 1
                    text_params = display_meta.text_params[0]
                    
                    # Create attribute text
                    attr_text = f"ID:{obj_meta.object_id} | {vehicle_color} | {vehicle_make_type}"
                    text_params.display_text = attr_text
                    
                    # Position text near the object bounding box
                    text_params.x_offset = int(obj_meta.rect_params.left)
                    text_params.y_offset = int(obj_meta.rect_params.top) - 30
                    
                    # Text styling
                    text_params.font_params.font_name = "Serif"
                    text_params.font_params.font_size = 10
                    text_params.font_params.font_color.set(1.0, 1.0, 0.0, 1.0)  # Yellow
                    text_params.set_bg_clr = 1
                    text_params.text_bg_clr.set(0.0, 0.0, 0.0, 0.7)  # Semi-transparent black
                    
                    pyds.nvds_add_display_meta_to_frame(frame_meta, display_meta)
                    
                    # Print vehicle info to console
                    print(f"  Vehicle ID:{obj_meta.object_id} - Color:{vehicle_color}, Make/Type:{vehicle_make_type}")
            
            try:
                l_obj = l_obj.next
            except StopIteration:
                break
        
        # Add frame summary display metadata
        display_meta = pyds.nvds_acquire_display_meta_from_pool(batch_meta)
        display_meta.num_labels = 1
        py_nvosd_text_params = display_meta.text_params[0]
        
        # Set display text
        py_nvosd_text_params.display_text = "Frame={} Objects={} Vehicles={} Persons={}".format(
            frame_number, num_rects, 
            obj_counter[PGIE_CLASS_ID_VEHICLE], 
            obj_counter[PGIE_CLASS_ID_PERSON]
        )
        
        # Position and style
        py_nvosd_text_params.x_offset = 10
        py_nvosd_text_params.y_offset = 12
        py_nvosd_text_params.font_params.font_name = "Serif"
        py_nvosd_text_params.font_params.font_size = 10
        py_nvosd_text_params.font_params.font_color.set(1.0, 1.0, 1.0, 1.0)  # White
        py_nvosd_text_params.set_bg_clr = 1
        py_nvosd_text_params.text_bg_clr.set(0.0, 0.0, 0.0, 1.0)  # Black background
        
        # Print frame summary to console
        print(pyds.get_string(py_nvosd_text_params.display_text))
        
        pyds.nvds_add_display_meta_to_frame(frame_meta, display_meta)
        
        try:
            l_frame = l_frame.next
        except StopIteration:
            break
    
    return Gst.PadProbeReturn.OK

# %%
# Attach probe to OSD element

osdsinkpad = nvosd.get_static_pad("sink")
if not osdsinkpad:
    sys.stderr.write("Unable to get sink pad of nvosd\n")
else:
    osdsinkpad.add_probe(Gst.PadProbeType.BUFFER, osd_sink_pad_buffer_probe, 0)
    print(" Metadata probe attached to OSD element")
# Out:
#  Metadata probe attached to OSD element

# %%
# Setup bus message handler

# Create event loop
loop = GLib.MainLoop()
bus = pipeline.get_bus()
bus.add_signal_watch()
bus.connect("message", bus_call, loop)

print(" Bus message handler configured")
# Out:
#  Bus message handler configured

# %%
# Run the pipeline

print("\n" + "="*60)
print("STARTING PIPELINE")
print("="*60)
print(f"Processing: {INPUT_VIDEO_NAME}")
print("="*60 + "\n")

start_time = time.time()

# Start pipeline
ret = pipeline.set_state(Gst.State.PLAYING)
if ret == Gst.StateChangeReturn.FAILURE:
    print(" ERROR: Unable to set pipeline to PLAYING state")
else:
    try:
        # Run event loop (blocks until EOS or error)
        loop.run()
    except KeyboardInterrupt:
        print("\n Interrupted by user")
    except Exception as e:
        print(f"\n Error: {e}")
    finally:
        # Cleanup
        print("\nCleaning up...")
        pipeline.set_state(Gst.State.NULL)
        
        elapsed_time = time.time() - start_time
        print(f"\n" + "="*60)
        print(f" PIPELINE COMPLETED")
        print(f"  Time elapsed: {elapsed_time:.2f} seconds")
        print(f" Output saved to: {OUTPUT_VIDEO_NAME}")
        print("="*60)
# Out:
# ============================================================
# STARTING PIPELINE
# ============================================================
# Processing: /opt/nvidia/deepstream/deepstream-8.0/samples/streams/sample_720p.h264
# ============================================================
# 0:00:02.713112463   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<secondary2-nvinference-engine> NvDsInferContext[UID 3]: Warning from NvDsInferContextImpl::deserializeEngineAndBackend() <nvdsinfer_context_impl.cpp:2097> [UID = 3]: deserialize engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleTypes/resnet18_vehicletypenet_pruned.onnx_b16_gpu0_fp16.engine failed
# 0:00:02.713155396   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<secondary2-nvinference-engine> NvDsInferContext[UID 3]: Warning from NvDsInferContextImpl::generateBackendContext() <nvdsinfer_context_impl.cpp:2202> [UID = 3]: deserialize backend context from engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleTypes/resnet18_vehicletypenet_pruned.onnx_b16_gpu0_fp16.engine failed, try rebuild
# 0:00:02.713162756   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<secondary2-nvinference-engine> NvDsInferContext[UID 3]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2123> [UID = 3]: Trying to create engine from model files
# 0:01:06.150632846   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<secondary2-nvinference-engine> NvDsInferContext[UID 3]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2155> [UID = 3]: serialize cuda engine to file: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleTypes/resnet18_vehicletypenet_pruned.onnx_b16_gpu0_fp16.engine successfully
# 0:01:06.293223449   267      0x40a3db0 INFO                 nvinfer gstnvinfer_impl.cpp:343:notifyLoadModelStatus:<secondary2-nvinference-engine> [UID 3]: Load new model:/app/notebooks/dstest2_sgie2_config.txt sucessfully
# 0:01:06.293411885   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<secondary1-nvinference-engine> NvDsInferContext[UID 2]: Warning from NvDsInferContextImpl::deserializeEngineAndBackend() <nvdsinfer_context_impl.cpp:2097> [UID = 2]: deserialize engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleMake/resnet18_vehiclemakenet_pruned.onnx_b16_gpu0_fp16.engine failed
# 0:01:06.293423765   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<secondary1-nvinference-engine> NvDsInferContext[UID 2]: Warning from NvDsInferContextImpl::generateBackendContext() <nvdsinfer_context_impl.cpp:2202> [UID = 2]: deserialize backend context from engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleMake/resnet18_vehiclemakenet_pruned.onnx_b16_gpu0_fp16.engine failed, try rebuild
# 0:01:06.293430626   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<secondary1-nvinference-engine> NvDsInferContext[UID 2]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2123> [UID = 2]: Trying to create engine from model files
# 0:02:10.941364883   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<secondary1-nvinference-engine> NvDsInferContext[UID 2]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2155> [UID = 2]: serialize cuda engine to file: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleMake/resnet18_vehiclemakenet_pruned.onnx_b16_gpu0_fp16.engine successfully
# 0:02:11.103427247   267      0x40a3db0 INFO                 nvinfer gstnvinfer_impl.cpp:343:notifyLoadModelStatus:<secondary1-nvinference-engine> [UID 2]: Load new model:/app/notebooks/dstest2_sgie1_config.txt sucessfully
# Opening in BLOCKING MODE
# WARNING: ../nvdsinfer/nvdsinfer_model_builder.cpp:1261 Deserialize engine failed because file path: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleTypes/resnet18_vehicletypenet_pruned.onnx_b16_gpu0_fp16.engine open error
# INFO: ../nvdsinfer/nvdsinfer_model_builder.cpp:363 [FullDims Engine Info]: layers num: 2
# 0   INPUT  kFLOAT input_1:0       3x224x224       min: 1x3x224x224     opt: 16x3x224x224    Max: 16x3x224x224
# 1   OUTPUT kFLOAT predictions/Softmax:0 6               min: 0               opt: 0               Max: 0
#
# WARNING: ../nvdsinfer/nvdsinfer_model_builder.cpp:1261 Deserialize engine failed because file path: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Secondary_VehicleMake/resnet18_vehiclemakenet_pruned.onnx_b16_gpu0_fp16.engine open error
# INFO: ../nvdsinfer/nvdsinfer_model_builder.cpp:363 [FullDims Engine Info]: layers num: 2
# 0   INPUT  kFLOAT input_1:0       3x224x224       min: 1x3x224x224     opt: 16x3x224x224    Max: 16x3x224x224
# 1   OUTPUT kFLOAT predictions/Softmax:0 20              min: 0               opt: 0               Max: 0
#
# gstnvtracker: Loading low-level lib at /opt/nvidia/deepstream/deepstream-8.0/lib/libnvds_nvmultiobjecttracker.so
# [NvMultiObjectTracker] Initialized
# 0:02:11.217961026   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Warning from NvDsInferContextImpl::deserializeEngineAndBackend() <nvdsinfer_context_impl.cpp:2097> [UID = 1]: deserialize engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Primary_Detector/resnet18_trafficcamnet_pruned.onnx_b1_gpu0_fp16.engine failed
# 0:02:11.218001338   267      0x40a3db0 WARN                 nvinfer gstnvinfer.cpp:682:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Warning from NvDsInferContextImpl::generateBackendContext() <nvdsinfer_context_impl.cpp:2202> [UID = 1]: deserialize backend context from engine from file :/opt/nvidia/deepstream/deepstream-8.0/samples/models/Primary_Detector/resnet18_trafficcamnet_pruned.onnx_b1_gpu0_fp16.engine failed, try rebuild
# 0:02:11.218023046   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2123> [UID = 1]: Trying to create engine from model files
# 0:03:20.748891410   267      0x40a3db0 INFO                 nvinfer gstnvinfer.cpp:685:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:2155> [UID = 1]: serialize cuda engine to file: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Primary_Detector/resnet18_trafficcamnet_pruned.onnx_b1_gpu0_fp16.engine successfully
# 0:03:20.918359930   267      0x40a3db0 INFO                 nvinfer gstnvinfer_impl.cpp:343:notifyLoadModelStatus:<primary-inference> [UID 1]: Load new model:/app/notebooks/dstest2_pgie_config.txt sucessfully
# Frame=0 Objects=0 Vehicles=0 Persons=0
# Frame=1 Objects=0 Vehicles=0 Persons=0
# Frame=2 Objects=13 Vehicles=8 Persons=5
#   Vehicle ID:5 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=3 Objects=14 Vehicles=8 Persons=6
#   Vehicle ID:5 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=4 Objects=12 Vehicles=7 Persons=5
#   Vehicle ID:5 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=5 Objects=12 Vehicles=7 Persons=5
#   Vehicle ID:5 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=6 Objects=12 Vehicles=7 Persons=5
#   Vehicle ID:5 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=7 Objects=11 Vehicles=7 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=8 Objects=15 Vehicles=10 Persons=5
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=9 Objects=11 Vehicles=7 Persons=4
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=10 Objects=12 Vehicles=8 Persons=4
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=11 Objects=13 Vehicles=9 Persons=4
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=12 Objects=13 Vehicles=9 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=13 Objects=14 Vehicles=10 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=14 Objects=13 Vehicles=9 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=15 Objects=13 Vehicles=8 Persons=5
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=16 Objects=13 Vehicles=8 Persons=5
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=17 Objects=11 Vehicles=7 Persons=4
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=18 Objects=11 Vehicles=7 Persons=4
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=19 Objects=11 Vehicles=5 Persons=6
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=20 Objects=14 Vehicles=8 Persons=6
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=21 Objects=12 Vehicles=7 Persons=5
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=22 Objects=14 Vehicles=10 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=23 Objects=15 Vehicles=11 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=24 Objects=16 Vehicles=12 Persons=4
#   Vehicle ID:5 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:16 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=25 Objects=15 Vehicles=12 Persons=3
#   Vehicle ID:16 - Color:acura, Make/Type:largevehicle
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:mercedes, Make/Type:suv
# Frame=26 Objects=12 Vehicles=9 Persons=3
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:Unknown, Make/Type:sedan
# Frame=27 Objects=11 Vehicles=9 Persons=2
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:Unknown, Make/Type:sedan
# Frame=28 Objects=11 Vehicles=9 Persons=2
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:chrysler, Make/Type:sedan
#   Vehicle ID:10 - Color:Unknown, Make/Type:sedan
# Frame=29 Objects=12 Vehicles=10 Persons=2
#   Vehicle ID:16 - Color:acura, Make/Type:largevehicle
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:25 - Color:chrysler, Make/Type:sedan
# Frame=30 Objects=13 Vehicles=11 Persons=2
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:chrysler, Make/Type:sedan
# Frame=31 Objects=15 Vehicles=13 Persons=2
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=32 Objects=16 Vehicles=14 Persons=2
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
# Frame=33 Objects=14 Vehicles=12 Persons=2
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
# Frame=34 Objects=13 Vehicles=10 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
# Frame=35 Objects=13 Vehicles=10 Persons=3
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
# Frame=36 Objects=15 Vehicles=12 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
# Frame=37 Objects=15 Vehicles=12 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
# Frame=38 Objects=16 Vehicles=13 Persons=3
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=39 Objects=14 Vehicles=11 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
# Frame=40 Objects=15 Vehicles=12 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
# Frame=41 Objects=16 Vehicles=12 Persons=4
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
# Frame=42 Objects=18 Vehicles=14 Persons=4
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
# Frame=43 Objects=17 Vehicles=13 Persons=4
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=44 Objects=16 Vehicles=13 Persons=3
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=45 Objects=20 Vehicles=16 Persons=4
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=46 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
# Frame=47 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
# Frame=48 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:25 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
# Frame=49 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
# Frame=50 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:mazda, Make/Type:sedan
# Frame=51 Objects=18 Vehicles=14 Persons=4
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:mazda, Make/Type:sedan
# Frame=52 Objects=16 Vehicles=13 Persons=3
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:mazda, Make/Type:sedan
# Frame=53 Objects=16 Vehicles=13 Persons=3
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:mazda, Make/Type:sedan
# Frame=54 Objects=20 Vehicles=16 Persons=4
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
# Frame=55 Objects=20 Vehicles=15 Persons=5
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:11 - Color:gmc, Make/Type:suv
# Frame=56 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:10 - Color:nissan, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:23 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=57 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:23 - Color:bmw, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=58 Objects=18 Vehicles=14 Persons=4
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:23 - Color:bmw, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=59 Objects=18 Vehicles=13 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:25 - Color:toyota, Make/Type:sedan
#   Vehicle ID:23 - Color:bmw, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=60 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=61 Objects=18 Vehicles=14 Persons=4
#   Vehicle ID:52 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=62 Objects=19 Vehicles=15 Persons=4
#   Vehicle ID:52 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=63 Objects=22 Vehicles=16 Persons=6
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=64 Objects=21 Vehicles=16 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=65 Objects=20 Vehicles=15 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=66 Objects=20 Vehicles=15 Persons=5
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:10 - Color:hyundai, Make/Type:sedan
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=67 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=68 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=69 Objects=19 Vehicles=14 Persons=5
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=70 Objects=19 Vehicles=14 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:suv
# Frame=71 Objects=22 Vehicles=17 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:23 - Color:mercedes, Make/Type:sedan
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:nissan, Make/Type:van
# Frame=72 Objects=24 Vehicles=18 Persons=6
#   Vehicle ID:23 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:nissan, Make/Type:van
# Frame=73 Objects=25 Vehicles=19 Persons=6
#   Vehicle ID:23 - Color:Unknown, Make/Type:suv
#   Vehicle ID:11 - Color:nissan, Make/Type:van
# Frame=74 Objects=24 Vehicles=18 Persons=6
#   Vehicle ID:23 - Color:Unknown, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:nissan, Make/Type:van
# Frame=75 Objects=24 Vehicles=17 Persons=7
#   Vehicle ID:23 - Color:Unknown, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:nissan, Make/Type:van
# Frame=76 Objects=24 Vehicles=18 Persons=6
#   Vehicle ID:23 - Color:Unknown, Make/Type:suv
#   Vehicle ID:11 - Color:nissan, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=77 Objects=20 Vehicles=16 Persons=4
#   Vehicle ID:23 - Color:Unknown, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:nissan, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=78 Objects=21 Vehicles=16 Persons=5
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=79 Objects=26 Vehicles=19 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=80 Objects=23 Vehicles=16 Persons=7
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:van
# Frame=81 Objects=23 Vehicles=17 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:van
# Frame=82 Objects=25 Vehicles=18 Persons=7
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:van
# Frame=83 Objects=23 Vehicles=18 Persons=5
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=84 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=85 Objects=21 Vehicles=14 Persons=7
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=86 Objects=19 Vehicles=14 Persons=5
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=87 Objects=20 Vehicles=15 Persons=5
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=88 Objects=22 Vehicles=16 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:infiniti, Make/Type:van
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
# Frame=89 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:52 - Color:Unknown, Make/Type:largevehicle
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:16 - Color:lexus, Make/Type:van
# Frame=90 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=91 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:suv
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=92 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:suv
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=93 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:65 - Color:chevrolet, Make/Type:truck
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=94 Objects=21 Vehicles=14 Persons=7
#   Vehicle ID:65 - Color:chevrolet, Make/Type:truck
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=95 Objects=23 Vehicles=16 Persons=7
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=96 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=97 Objects=18 Vehicles=12 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=98 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:16 - Color:lexus, Make/Type:van
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:toyota, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=99 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:11 - Color:toyota, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=100 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:sedan
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:toyota, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=101 Objects=18 Vehicles=13 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:toyota, Make/Type:van
# Frame=102 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
# Frame=103 Objects=21 Vehicles=13 Persons=8
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=104 Objects=23 Vehicles=15 Persons=8
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
# Frame=105 Objects=22 Vehicles=14 Persons=8
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
# Frame=106 Objects=18 Vehicles=11 Persons=7
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
# Frame=107 Objects=21 Vehicles=13 Persons=8
#   Vehicle ID:18 - Color:toyota, Make/Type:coupe
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
# Frame=108 Objects=18 Vehicles=12 Persons=6
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
# Frame=109 Objects=18 Vehicles=11 Persons=7
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
# Frame=110 Objects=20 Vehicles=13 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
# Frame=111 Objects=16 Vehicles=10 Persons=6
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
# Frame=112 Objects=16 Vehicles=10 Persons=6
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=113 Objects=16 Vehicles=9 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=114 Objects=16 Vehicles=9 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=115 Objects=19 Vehicles=12 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=116 Objects=16 Vehicles=10 Persons=6
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=117 Objects=19 Vehicles=12 Persons=7
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:56 - Color:jeep, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=118 Objects=20 Vehicles=13 Persons=7
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=119 Objects=18 Vehicles=11 Persons=7
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:ford, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=120 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=121 Objects=17 Vehicles=12 Persons=5
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=122 Objects=18 Vehicles=13 Persons=5
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=123 Objects=18 Vehicles=12 Persons=6
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:Unknown, Make/Type:van
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=124 Objects=21 Vehicles=14 Persons=7
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
# Frame=125 Objects=19 Vehicles=12 Persons=7
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:56 - Color:nissan, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
# Frame=126 Objects=20 Vehicles=12 Persons=8
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
# Frame=127 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=128 Objects=18 Vehicles=11 Persons=7
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=129 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:79 - Color:subaru, Make/Type:Unknown
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
# Frame=130 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:79 - Color:subaru, Make/Type:Unknown
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
# Frame=131 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=132 Objects=16 Vehicles=9 Persons=7
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=133 Objects=17 Vehicles=9 Persons=8
#   Vehicle ID:11 - Color:kia, Make/Type:van
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=134 Objects=18 Vehicles=10 Persons=8
#   Vehicle ID:19 - Color:chevrolet, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=135 Objects=18 Vehicles=10 Persons=8
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=136 Objects=19 Vehicles=11 Persons=8
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=137 Objects=18 Vehicles=10 Persons=8
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=138 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=139 Objects=17 Vehicles=10 Persons=7
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=140 Objects=20 Vehicles=12 Persons=8
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=141 Objects=18 Vehicles=12 Persons=6
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=142 Objects=20 Vehicles=13 Persons=7
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=143 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:65 - Color:chevrolet, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=144 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:65 - Color:chevrolet, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=145 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:65 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=146 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:suv
# Frame=147 Objects=20 Vehicles=15 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:mercedes, Make/Type:truck
# Frame=148 Objects=19 Vehicles=14 Persons=5
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:65 - Color:mercedes, Make/Type:Unknown
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:mercedes, Make/Type:truck
# Frame=149 Objects=21 Vehicles=14 Persons=7
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:65 - Color:mercedes, Make/Type:Unknown
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:mercedes, Make/Type:truck
# Frame=150 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:65 - Color:mercedes, Make/Type:Unknown
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:mercedes, Make/Type:truck
# Frame=151 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=152 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=153 Objects=22 Vehicles=16 Persons=6
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=154 Objects=23 Vehicles=16 Persons=7
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=155 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=156 Objects=22 Vehicles=16 Persons=6
#   Vehicle ID:65 - Color:mercedes, Make/Type:coupe
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=157 Objects=24 Vehicles=18 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=158 Objects=23 Vehicles=16 Persons=7
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=159 Objects=19 Vehicles=13 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=160 Objects=18 Vehicles=13 Persons=5
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=161 Objects=22 Vehicles=15 Persons=7
#   Vehicle ID:86 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=162 Objects=21 Vehicles=15 Persons=6
#   Vehicle ID:86 - Color:ford, Make/Type:largevehicle
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=163 Objects=20 Vehicles=14 Persons=6
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:toyota, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=164 Objects=24 Vehicles=17 Persons=7
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:toyota, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=165 Objects=24 Vehicles=16 Persons=8
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=166 Objects=25 Vehicles=15 Persons=9
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=167 Objects=22 Vehicles=14 Persons=7
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=168 Objects=23 Vehicles=14 Persons=8
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=169 Objects=25 Vehicles=15 Persons=9
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=170 Objects=24 Vehicles=16 Persons=7
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=171 Objects=23 Vehicles=15 Persons=7
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=172 Objects=21 Vehicles=13 Persons=8
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=173 Objects=21 Vehicles=14 Persons=6
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=174 Objects=22 Vehicles=15 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:bmw, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:19 - Color:ford, Make/Type:truck
# Frame=175 Objects=23 Vehicles=16 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:Unknown, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=176 Objects=24 Vehicles=16 Persons=7
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:Unknown, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
# Frame=177 Objects=21 Vehicles=14 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:Unknown, Make/Type:suv
# Frame=178 Objects=22 Vehicles=15 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:82 - Color:Unknown, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=179 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=180 Objects=24 Vehicles=17 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=181 Objects=25 Vehicles=17 Persons=7
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=182 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=183 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=184 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:19 - Color:ford, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=185 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=186 Objects=24 Vehicles=17 Persons=6
#   Vehicle ID:87 - Color:nissan, Make/Type:sedan
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=187 Objects=24 Vehicles=17 Persons=6
#   Vehicle ID:87 - Color:dodge, Make/Type:sedan
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=188 Objects=26 Vehicles=19 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
# Frame=189 Objects=24 Vehicles=18 Persons=6
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:12 - Color:nissan, Make/Type:suv
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
# Frame=190 Objects=23 Vehicles=17 Persons=6
#   Vehicle ID:50 - Color:honda, Make/Type:suv
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:12 - Color:Unknown, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
# Frame=191 Objects=21 Vehicles=14 Persons=6
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
# Frame=192 Objects=24 Vehicles=16 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
# Frame=193 Objects=25 Vehicles=17 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
# Frame=194 Objects=24 Vehicles=17 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:98 - Color:bmw, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
# Frame=195 Objects=22 Vehicles=15 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:98 - Color:Unknown, Make/Type:sedan
# Frame=196 Objects=21 Vehicles=14 Persons=6
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
# Frame=197 Objects=22 Vehicles=14 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:98 - Color:Unknown, Make/Type:sedan
# Frame=198 Objects=25 Vehicles=17 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:97 - Color:Unknown, Make/Type:suv
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:Unknown, Make/Type:sedan
# Frame=199 Objects=26 Vehicles=18 Persons=8
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:Unknown, Make/Type:sedan
# Frame=200 Objects=25 Vehicles=18 Persons=7
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:honda, Make/Type:sedan
# Frame=201 Objects=22 Vehicles=16 Persons=6
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:honda, Make/Type:sedan
# Frame=202 Objects=23 Vehicles=16 Persons=6
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:acura, Make/Type:sedan
# Frame=203 Objects=23 Vehicles=15 Persons=8
#   Vehicle ID:12 - Color:toyota, Make/Type:sedan
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:acura, Make/Type:sedan
# Frame=204 Objects=24 Vehicles=17 Persons=7
#   Vehicle ID:82 - Color:mercedes, Make/Type:suv
#   Vehicle ID:98 - Color:acura, Make/Type:sedan
#   Vehicle ID:50 - Color:honda, Make/Type:suv
# Frame=205 Objects=25 Vehicles=18 Persons=6
#   Vehicle ID:82 - Color:toyota, Make/Type:suv
# ...
#   Vehicle ID:440 - Color:audi, Make/Type:Unknown
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1367 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1368 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1369 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1370 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1371 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1372 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1373 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1374 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1375 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1376 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1377 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1378 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1379 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1380 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:464 - Color:bmw, Make/Type:largevehicle
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:440 - Color:audi, Make/Type:sedan
# Frame=1381 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:464 - Color:bmw, Make/Type:largevehicle
#   Vehicle ID:440 - Color:bmw, Make/Type:sedan
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1382 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:464 - Color:bmw, Make/Type:largevehicle
#   Vehicle ID:440 - Color:bmw, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1383 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:440 - Color:bmw, Make/Type:suv
#   Vehicle ID:464 - Color:bmw, Make/Type:largevehicle
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1384 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1385 Objects=21 Vehicles=19 Persons=2
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1386 Objects=22 Vehicles=20 Persons=2
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1387 Objects=21 Vehicles=19 Persons=2
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1388 Objects=20 Vehicles=18 Persons=2
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1389 Objects=20 Vehicles=18 Persons=2
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:440 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1390 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:468 - Color:honda, Make/Type:largevehicle
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1391 Objects=18 Vehicles=16 Persons=2
#   Vehicle ID:468 - Color:honda, Make/Type:largevehicle
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1392 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:468 - Color:honda, Make/Type:largevehicle
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1393 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:468 - Color:honda, Make/Type:largevehicle
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1394 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:468 - Color:honda, Make/Type:largevehicle
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1395 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1396 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1397 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1398 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1399 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1400 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1401 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1402 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1403 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
# Frame=1404 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
# Frame=1405 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1406 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1407 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
# Frame=1408 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1409 Objects=22 Vehicles=20 Persons=2
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1410 Objects=20 Vehicles=18 Persons=2
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1411 Objects=21 Vehicles=19 Persons=2
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1412 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1413 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1414 Objects=24 Vehicles=20 Persons=4
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1415 Objects=23 Vehicles=19 Persons=4
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1416 Objects=24 Vehicles=20 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:474 - Color:gmc, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1417 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:honda, Make/Type:sedan
#   Vehicle ID:474 - Color:gmc, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1418 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:474 - Color:gmc, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1419 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:Unknown, Make/Type:suv
# Frame=1420 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:374 - Color:mercedes, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:474 - Color:Unknown, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1421 Objects=24 Vehicles=20 Persons=4
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1422 Objects=22 Vehicles=18 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
# Frame=1423 Objects=21 Vehicles=17 Persons=4
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1424 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:474 - Color:jeep, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1425 Objects=20 Vehicles=17 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:480 - Color:mercedes, Make/Type:largevehicle
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1426 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:480 - Color:mercedes, Make/Type:van
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1427 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1428 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1429 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
# Frame=1430 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:451 - Color:Unknown, Make/Type:coupe
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1431 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:480 - Color:mercedes, Make/Type:van
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1432 Objects=22 Vehicles=19 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:480 - Color:mercedes, Make/Type:van
#   Vehicle ID:474 - Color:chevrolet, Make/Type:suv
# Frame=1433 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:464 - Color:bmw, Make/Type:largevehicle
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:chevrolet, Make/Type:suv
# Frame=1434 Objects=23 Vehicles=20 Persons=3
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:474 - Color:chevrolet, Make/Type:suv
# Frame=1435 Objects=21 Vehicles=18 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1436 Objects=23 Vehicles=20 Persons=3
#   Vehicle ID:437 - Color:Unknown, Make/Type:suv
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1437 Objects=22 Vehicles=19 Persons=3
# WARNING: ../nvdsinfer/nvdsinfer_model_builder.cpp:1261 Deserialize engine failed because file path: /opt/nvidia/deepstream/deepstream-8.0/samples/models/Primary_Detector/resnet18_trafficcamnet_pruned.onnx_b1_gpu0_fp16.engine open error
# INFO: ../nvdsinfer/nvdsinfer_model_builder.cpp:363 [Implicit Engine Info]: layers num: 0
#
# nvstreammux: Successfully handled EOS for source_id=0
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1438 Objects=23 Vehicles=20 Persons=3
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:480 - Color:ford, Make/Type:van
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1439 Objects=23 Vehicles=20 Persons=3
#   Vehicle ID:436 - Color:nissan, Make/Type:suv
#   Vehicle ID:478 - Color:Unknown, Make/Type:sedan
#   Vehicle ID:474 - Color:nissan, Make/Type:suv
# Frame=1440 Objects=23 Vehicles=20 Persons=3
# Frame=1441 Objects=0 Vehicles=0 Persons=0
# End-of-stream
#
# Cleaning up...
#
# ============================================================
#  PIPELINE COMPLETED
#   Time elapsed: 219.00 seconds
#  Output saved to: /app/notebooks/ds_out_multiclass.mp4
# ============================================================

# %%
# Check output file

import os

if os.path.exists(OUTPUT_VIDEO_NAME):
    file_size = os.path.getsize(OUTPUT_VIDEO_NAME)
    print(f" Output file exists")
    print(f" Location: {OUTPUT_VIDEO_NAME}")
    print(f" Size: {file_size / (1024*1024):.2f} MB")
    print(f"\n On your host machine: ~/deepstream8/notebooks/ds_out_multiclass.mp4")
else:
    print(f" Output file not found: {OUTPUT_VIDEO_NAME}")
# Out:
#  Output file exists
#  Location: /app/notebooks/ds_out_multiclass.mp4
#  Size: 22.67 MB
#
#  On your host machine: ~/deepstream8/notebooks/ds_out_multiclass.mp4

# %%
# Alternative: Display video with HTML5 player

from IPython.display import HTML
import os

if os.path.exists(OUTPUT_VIDEO_NAME):
    # Create HTML5 video player
    html = f"""
    <div style="text-align: center; margin: 20px;">
        <h3>DeepStream Output Video</h3>
        <video width="800" controls>
            <source src="ds_out_multiclass.mp4" type="video/mp4">
            Your browser does not support the video tag.
        </video>
        <p style="margin-top: 10px;">
            <strong>File:</strong> ds_out_multiclass.mp4 | 
            <strong>Size:</strong> {os.path.getsize(OUTPUT_VIDEO_NAME) / (1024*1024):.2f} MB
        </p>
    </div>
    """
    display(HTML(html))
else:
    print(f"Video not found: {OUTPUT_VIDEO_NAME}")
# Out:
#     <div style="text-align: center; margin: 20px;">
#         <h3>DeepStream Output Video</h3>
#         <video width="800" controls>
#             <source src="ds_out_multiclass.mp4" type="video/mp4">
#             Your browser does not support the video tag.
#         </video>
#         <p style="margin-top: 10px;">
#             <strong>File:</strong> ds_out_multiclass.mp4 |
#             <strong>Size:</strong> 22.67 MB
#         </p>
#     </div>
